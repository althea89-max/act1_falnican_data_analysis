# %% [markdown]
# <h1>ACTIVTY 1- PALMER PENGUINS DATA ANALYTICS PROJECT</h1>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>Analyst: Althea Bianca P. Falnican</h2>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import f_oneway

# %%
penguin = pd.read_csv ('datasets\\penguins.csv')

# %%
penguin
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h1>DESCRIPTIVE ANALYTICS</h1>

# %%
penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# <h1>FILTERING A COLUMN</h1>

# %%
adelie_df = penguin[penguin['species'] == "Adelie"]

# %%
adelie_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
adelie_df['body_mass_g'].mean()
# Out:
# np.float64(3700.662251655629)

# %%
penguin['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3         NaN
# 4      female
#         ...
# 339      male
# 340    female
# 341      male
# 342      male
# 343    female
# Name: sex, Length: 344, dtype: object

# %%
penguin['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguin['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
penguin[penguin['island'] == 'Dream']
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      Adelie  Dream            39.5           16.7              178.0
# 31      Adelie  Dream            37.2           18.1              178.0
# 32      Adelie  Dream            39.5           17.8              188.0
# 33      Adelie  Dream            40.9           18.9              184.0
# 34      Adelie  Dream            36.4           17.0              195.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 30        3250.0  female  2007
# 31        3900.0    male  2007
# ...

# %%
penguin[(penguin['species'] == 'Adelie') & (penguin['island'] == 'Dream')]
# Out:
#     species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30   Adelie  Dream            39.5           16.7              178.0
# 31   Adelie  Dream            37.2           18.1              178.0
# 32   Adelie  Dream            39.5           17.8              188.0
# 33   Adelie  Dream            40.9           18.9              184.0
# 34   Adelie  Dream            36.4           17.0              195.0
# 35   Adelie  Dream            39.2           21.1              196.0
# 36   Adelie  Dream            38.8           20.0              190.0
# 37   Adelie  Dream            42.2           18.5              180.0
# 38   Adelie  Dream            37.6           19.3              181.0
# 39   Adelie  Dream            39.8           19.1              184.0
# 40   Adelie  Dream            36.5           18.0              182.0
# 41   Adelie  Dream            40.8           18.4              195.0
# 42   Adelie  Dream            36.0           18.5              186.0
# ...

# %%
adelie_dream_df = penguin[(penguin['species'] =='Adelie') & (penguin['island'] == 'Dream')]

# %%
adelie_dream_df
# Out:
#     species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30   Adelie  Dream            39.5           16.7              178.0
# 31   Adelie  Dream            37.2           18.1              178.0
# 32   Adelie  Dream            39.5           17.8              188.0
# 33   Adelie  Dream            40.9           18.9              184.0
# 34   Adelie  Dream            36.4           17.0              195.0
# 35   Adelie  Dream            39.2           21.1              196.0
# 36   Adelie  Dream            38.8           20.0              190.0
# 37   Adelie  Dream            42.2           18.5              180.0
# 38   Adelie  Dream            37.6           19.3              181.0
# 39   Adelie  Dream            39.8           19.1              184.0
# 40   Adelie  Dream            36.5           18.0              182.0
# 41   Adelie  Dream            40.8           18.4              195.0
# 42   Adelie  Dream            36.0           18.5              186.0
# ...

# %%
penguin[(penguin['body_mass_g'] >= 4000) & (penguin['species'] == 'Adelie')]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 17   Adelie  Torgersen            42.5           20.7              197.0
# 19   Adelie  Torgersen            46.0           21.5              194.0
# 35   Adelie      Dream            39.2           21.1              196.0
# 39   Adelie      Dream            39.8           19.1              184.0
# 43   Adelie      Dream            44.1           19.7              196.0
# 45   Adelie      Dream            39.6           18.8              190.0
# 49   Adelie      Dream            42.3           21.2              191.0
# 51   Adelie     Biscoe            40.1           18.9              188.0
# 53   Adelie     Biscoe            42.0           19.5              200.0
# ...

# %% [markdown]
# <h1>CLEANING THE DATA</h1>

# %%
penguin.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False           False          False              False
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex   year
# 0          False  False  False
# 1          False  False  False
# ...

# %%
penguin.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h2>WHAT TO DO WITH THE NULL VALUES?</h2>

# %%
penguin['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguin['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %% [markdown]
# <h3>HOW TO FILLUP NULL VALUES?</h3>

# %%
penguin['bill_length_mm'] = penguin['bill_length_mm'].fillna(penguin['bill_length_mm'].mean())
penguin['bill_depth_mm'] = penguin['bill_depth_mm'].fillna(penguin['bill_depth_mm'].mean())
penguin['flipper_length_mm'] = penguin['flipper_length_mm'].fillna(penguin['flipper_length_mm'].mean())
penguin['body_mass_g'] = penguin['body_mass_g'].fillna(penguin['body_mass_g'].mean())

# %% [markdown]
# <h1>QUESTIONS</h1>

# %% [markdown]
# <h1>WHAT GENDER IS MORE DOMINANT AT ISLAND DREAM?</h1>

# %%
sps_isd_x = penguin.groupby(['sex', 'island']).size()

# %%
sps_isd_x
# Out:
# sex     island
# female  Biscoe       80
#         Dream        61
#         Torgersen    24
# male    Biscoe       83
#         Dream        62
#         Torgersen    23
# dtype: int64

# %% [markdown]
# <h3>INSIGHTS:
# The more dominant sex in the island Dream is male penguins.</h3>

# %% [markdown]
# <h1>WHO GOT THE MOST LONGEST FLIPPER LENGTH IN ANY SPECIES?</h1>

# %%
species_flipper = penguin.groupby(['species', 'island'])['flipper_length_mm'].mean()

# %%
species_flipper
# Out:
# species    island
# Adelie     Biscoe       188.795455
#            Dream        189.732143
#            Torgersen    191.382985
# Chinstrap  Dream        195.823529
# Gentoo     Biscoe       217.055768
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# <h3>INSIGHTS:
# According to the result, the species who got the longest flipper length is Gentoo from the island Biscoe, who got 217.055768</h3>

# %% [markdown]
# <h1>IS THERE A CORRELATION BETWEEN BILL LENGTH AND SPECIES?</h1>

# %%
penguin[penguin['species'] == 'Gentoo']['bill_length_mm']
# Out:
# 152    46.10000
# 153    50.00000
# 154    48.70000
# 155    50.00000
# 156    47.60000
#          ...
# 271    43.92193
# 272    46.80000
# 273    50.40000
# 274    45.20000
# 275    49.90000
# Name: bill_length_mm, Length: 124, dtype: float64

# %%
penguin[penguin['species'] == 'Adelie']['flipper_length_mm']
# Out:
# 0      181.000000
# 1      186.000000
# 2      195.000000
# 3      200.915205
# 4      193.000000
#           ...
# 147    184.000000
# 148    195.000000
# 149    193.000000
# 150    187.000000
# 151    201.000000
# Name: flipper_length_mm, Length: 152, dtype: float64

# %%
penguin[penguin['species'] == 'Chinstrap']['flipper_length_mm']
# Out:
# 276    192.0
# 277    196.0
# 278    193.0
# 279    188.0
# 280    197.0
#        ...
# 339    207.0
# 340    202.0
# 341    193.0
# 342    210.0
# 343    198.0
# Name: flipper_length_mm, Length: 68, dtype: float64

# %%
f_oneway(penguin[penguin['species'] == 'Gentoo']['bill_length_mm'], penguin[penguin['species'] == 'Adelie']['bill_length_mm'], penguin[penguin['species'] == 'Chinstrap']['bill_length_mm'])
# Out:
# F_onewayResult(statistic=np.float64(405.48163827781104), pvalue=np.float64(7.233266188149726e-91))

# %% [markdown]
# <h3>INSIGHTS:
# According to the result, there is a correlation between bill length and species.</h3>

# %% [markdown]
# <h1>WHO ARE THE HEAVIEST AMONG THE SPECIES?</h1>

# %%
species_flipper = penguin.groupby(['species', 'island'])['body_mass_g'].mean()

# %%
species_flipper
# Out:
# species    island
# Adelie     Biscoe       3709.659091
#            Dream        3688.392857
#            Torgersen    3715.899123
# Chinstrap  Dream        3733.088235
# Gentoo     Biscoe       5068.965761
# Name: body_mass_g, dtype: float64

# %% [markdown]
# <h3>INSIGHTS:
# According to the result, the heaviest among the species are the Gentoo</h3>

# %% [markdown]
# <h1>IN WHAT YEAR GOT THE MOST SHORTEST BILL DEPTH?</h1>

# %%
species_bill_depth = penguin.groupby(['species', 'island', 'year'])['bill_depth_mm'].mean()

# %%
species_bill_depth
# Out:
# species    island     year
# Adelie     Biscoe     2007    18.440000
#                       2008    18.127778
#                       2009    18.600000
#            Dream      2007    18.690000
#                       2008    18.337500
#                       2009    17.745000
#            Torgersen  2007    18.927558
#                       2008    18.118750
#                       2009    18.037500
# Chinstrap  Dream      2007    18.484615
#                       2008    18.450000
#                       2009    18.329167
# Gentoo     Biscoe     2007    14.688235
#                       2008    14.923913
#                       2009    15.319345
# Name: bill_depth_mm, dtype: float64

# %% [markdown]
# <h3>INSIGHTS:
# According to the results, the most shortest bill depth was during at the year of 2007, which is the penguin Gentoo at the island of Biscoe, who got 14.688235</h3>

# %% [markdown]
# <h1>IN WHAT YEAR GOT THE MOST LONGEST BILL LENGTH?</h1>

# %%
species_billlength = penguin.groupby(['species', 'island', 'year'])['bill_length_mm'].mean()

# %%
species_billlength
# Out:
# species    island     year
# Adelie     Biscoe     2007    38.320000
#                       2008    38.700000
#                       2009    39.693750
#            Dream      2007    39.100000
#                       2008    38.193750
#                       2009    38.150000
#            Torgersen  2007    39.056096
#                       2008    38.768750
#                       2009    39.312500
# Chinstrap  Dream      2007    48.723077
#                       2008    48.700000
#                       2009    49.054167
# Gentoo     Biscoe     2007    47.014706
#                       2008    46.936957
#                       2009    48.395953
# Name: bill_length_mm, dtype: float64

# %% [markdown]
# <h3>INSIGHTS:
# According to the results, the most longest bill length in a year was during the year 2009 which is the penguin Chinstrap at the island of Dream, who got the 49.054167</h3>

# %% [markdown]
# <h1>What is the average body mass of penguins on island Torgersen?</h1>

# %%
penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      344.000000     344.000000         344.000000   344.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.443643       1.969027          14.020657   799.613058
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguin.loc[penguin["island"]=="Torgersen","body_mass_g"].mean()
# Out:
# np.float64(3715.8991228070176)

# %% [markdown]
# <h3>INSIGHTS:
# According to the result, the average body mass of a penguin in island Torgersen is 3715.8991228070176 </h3>

# %% [markdown]
# <h1>IS THERE A CORRELATION BETWEEN BILL DEPTH AND SPECIES?</h1>

# %%
penguin[penguin['species'] == 'Gentoo']['bill_length_mm']
# Out:
# 152    46.10000
# 153    50.00000
# 154    48.70000
# 155    50.00000
# 156    47.60000
#          ...
# 271    43.92193
# 272    46.80000
# 273    50.40000
# 274    45.20000
# 275    49.90000
# Name: bill_length_mm, Length: 124, dtype: float64

# %%
penguin[penguin['species'] == 'Adelie']['bill_length_mm']
# Out:
# 0      39.10000
# 1      39.50000
# 2      40.30000
# 3      43.92193
# 4      36.70000
#          ...
# 147    36.60000
# 148    36.00000
# 149    37.80000
# 150    36.00000
# 151    41.50000
# Name: bill_length_mm, Length: 152, dtype: float64

# %%
penguin[penguin['species'] == 'Chinstrap']['bill_length_mm']
# Out:
# 276    46.5
# 277    50.0
# 278    51.3
# 279    45.4
# 280    52.7
#        ...
# 339    55.8
# 340    43.5
# 341    49.6
# 342    50.8
# 343    50.2
# Name: bill_length_mm, Length: 68, dtype: float64

# %%
f_oneway(penguin[penguin['species'] == 'Gentoo']['bill_length_mm'], penguin[penguin['species'] == 'Adelie']['bill_length_mm'], penguin[penguin['species'] == 'Chinstrap']['bill_length_mm'])
# Out:
# F_onewayResult(statistic=np.float64(405.48163827781104), pvalue=np.float64(7.233266188149726e-91))

# %% [markdown]
# <H3>INSIGHTS:
# According to the result, There is a correlation between Bill Depth to the Species.</H3>

# %% [markdown]
# <h1>IS THERE A CORRELATION BETWEEN FLIPPER LENGTH AND SPECIES?</h1>

# %%
penguin[penguin['species'] == 'Gentoo']['flipper_length_mm']
# Out:
# 152    211.000000
# 153    230.000000
# 154    210.000000
# 155    218.000000
# 156    215.000000
#           ...
# 271    200.915205
# 272    215.000000
# 273    222.000000
# 274    212.000000
# 275    213.000000
# Name: flipper_length_mm, Length: 124, dtype: float64

# %%
penguin[penguin['species'] == 'Adelie']['flipper_length_mm']
# Out:
# 0      181.000000
# 1      186.000000
# 2      195.000000
# 3      200.915205
# 4      193.000000
#           ...
# 147    184.000000
# 148    195.000000
# 149    193.000000
# 150    187.000000
# 151    201.000000
# Name: flipper_length_mm, Length: 152, dtype: float64

# %%
penguin[penguin['species'] == 'Chinstrap']['flipper_length_mm']
# Out:
# 276    192.0
# 277    196.0
# 278    193.0
# 279    188.0
# 280    197.0
#        ...
# 339    207.0
# 340    202.0
# 341    193.0
# 342    210.0
# 343    198.0
# Name: flipper_length_mm, Length: 68, dtype: float64

# %%
f_oneway(penguin[penguin['species'] == 'Gentoo']['flipper_length_mm'], penguin[penguin['species'] == 'Adelie']['flipper_length_mm'], penguin[penguin['species'] == 'Chinstrap']['flipper_length_mm'])
# Out:
# F_onewayResult(statistic=np.float64(579.1597112667403), pvalue=np.float64(2.2113941068282237e-110))

# %% [markdown]
# <h3>INSIGHTS:
#     According to the result, There is a correlation between the species and it's flipper length.</h3>

# %% [markdown]
# <h1>WHAT IS THE AVERAGE FLIPPER LENGTH OF A CHINSTRAP SPECIES?</h1>

# %%
species_flipper_length = penguin.groupby(['species', 'island'])['flipper_length_mm'].mean()

# %%
species_flipper_length
# Out:
# species    island
# Adelie     Biscoe       188.795455
#            Dream        189.732143
#            Torgersen    191.382985
# Chinstrap  Dream        195.823529
# Gentoo     Biscoe       217.055768
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# <h3>INSIGTHS:
# According to the result, the average flipper length that the chinstrap got is 195.823529 at the island of Dream.</h3>

# %% [markdown]
# <h1>WHAT IS THE AVERAGE BILL LENGTH OF A ADELIE SPECIES AT THE ISLAND OF TORGERSEN?</h1>

# %%
species_bill_length = penguin.groupby(['species', 'island'])['bill_length_mm'].mean()

# %%
species_bill_length
# Out:
# species    island
# Adelie     Biscoe       38.975000
#            Dream        38.501786
#            Torgersen    39.046576
# Chinstrap  Dream        48.833824
# Gentoo     Biscoe       47.475983
# Name: bill_length_mm, dtype: float64

# %% [markdown]
# <h3>INSIGHTS:
# According to the result, the average bill length that the Adelie got is 39.046576 at the island of Torgersen. </h3>

# %% [markdown]
# <h1>WHAT IS THE AVERAGE BILL DEPTH OF GENTOO AT THE ISLAND OF BISCOE?</h1>

# %%
species_bill_depth = penguin.groupby(['species', 'island'])['bill_depth_mm'].mean()

# %%
species_bill_depth
# Out:
# species    island
# Adelie     Biscoe       18.370455
#            Dream        18.251786
#            Torgersen    18.404830
# Chinstrap  Dream        18.420588
# Gentoo     Biscoe       14.999606
# Name: bill_depth_mm, dtype: float64

# %% [markdown]
# <h3>INSIGHTS: According to the result the average bill depth of the Gentoo penguins have is 14.999606 at the island of Biscoe. </h3>

# %% [markdown]
# <h1>DATA VISUALIZATION</h1>

# %%
import matplotlib.pyplot as plt

# %%
penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      344.000000     344.000000         344.000000   344.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.443643       1.969027          14.020657   799.613058
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguin_count = penguin['species'].value_counts()

# %%
penguin_count.values
# Out:
# array([152, 124,  68])

# %%
#plt.bar(x, y, optional_values ....)
plt.bar(penguin_count.index, penguin_count.values, color= ['brown', 'pink', 'violet'])
plt.xlabel("Species")
plt.ylabel("Population")
plt.show()

# %%
penguin.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %%
#plt.bar(x, y, optional_values ....)
plt.scatter(penguin['body_mass_g'],penguin['flipper_length_mm'])
plt.xlabel("Body Mass")
plt.ylabel("Filpper Length")
plt.show()
